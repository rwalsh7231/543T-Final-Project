# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
import DiseaseAnalysis

# %%
# Total pop, infection rate, recovery rate, death rate, crossInfectivity, StartInfected, quarantine leak rate, quarantine time
group1 = DiseaseAnalysis.Population(10000, 0.25, 0.05, 0.05, 0.01, False, 1, 1)

group2 = DiseaseAnalysis.Population(100000, 0.3, 0.01, 0.01, 0.01, True, 1, 1)

# %%
S = [group1.S + group2.S]
I = [group1.I + group2.I]
R = [group1.R + group2.R]
D = [group1.D + group2.D]

for i in range(100):
    group1.SIRD()
    group2.SIRD()
    
    DiseaseAnalysis.crossInfect(group1, group2)
    
    S.append(group1.S + group2.S)
    I.append(group1.I + group2.I)
    R.append(group1.R + group2.R)
    D.append(group1.D + group2.D)
    
print(S[-1] + I[-1] + R[-1] + D[-1])
# Out:
# 109999.99999999999

# %%
plt.plot(S, label="S")
plt.plot(I, label="I")
plt.plot(R, label="R")
plt.plot(D, label="D")
plt.xlabel("Time")
plt.ylabel("Populations")
plt.title("SIRD MODEL SIMULATION")
plt.legend()
plt.show()

# %%
# Total pop, infection rate, recovery rate, death rate, crossInfectivity, StartInfected, quarantine leak rate, quarantine time
group3 = DiseaseAnalysis.Population(100, 0.50, 0.1, 0.05, 0.01, True, 0.25, 14)

S = [group3.S]
I = [group3.I]
R = [group3.R]
D = [group3.D]

while group3.I > 0.1:
    group3.SIRD()
    
    S.append(group3.S)
    I.append(group3.I)
    R.append(group3.R)
    D.append(group3.D)
    
print(S[-1] + I[-1] + R[-1] + D[-1])

plt.plot(S, label="S")
plt.plot(I, label="I")
plt.plot(R, label="R")
plt.plot(D, label="D")
plt.xlabel("Time")
plt.ylabel("Populations")
plt.title("SIRD MODEL SIMULATION")
plt.legend()
plt.show()

print("Total Deaths: {}".format(D[-1]))
# Out:
# 100.00000000000006
# Total Deaths: 10.12721917039022

# %%
# Out:
# 1 Days of Quarantine Tested, 32.23740656091513 deaths
# 2 Days of Quarantine Tested, 31.214870671555907 deaths
# 3 Days of Quarantine Tested, 29.64359601636416 deaths
# 4 Days of Quarantine Tested, 27.356729609017393 deaths
# 5 Days of Quarantine Tested, 24.1800959772234 deaths
# 6 Days of Quarantine Tested, 19.97604661693373 deaths
# 7 Days of Quarantine Tested, 14.80014309368634 deaths
# 8 Days of Quarantine Tested, 9.451618353647694 deaths
# 9 Days of Quarantine Tested, 5.6835214736220605 deaths
# 10 Days of Quarantine Tested, 3.8398536034986974 deaths
# 11 Days of Quarantine Tested, 2.9553228166451317 deaths
# 12 Days of Quarantine Tested, 2.4726074581147666 deaths
# 13 Days of Quarantine Tested, 2.1770110481531733 deaths
# 14 Days of Quarantine Tested, 1.979234452651406 deaths
# 15 Days of Quarantine Tested, 1.8396857533100412 deaths
# 16 Days of Quarantine Tested, 1.7408050878237005 deaths
# 17 Days of Quarantine Tested, 1.6667967308985883 deaths
# 18 Days of Quarantine Tested, 1.6070950710051792 deaths
# 19 Days of Quarantine Tested, 1.5632408486695146 deaths
# 20 Days of Quarantine Tested, 1.5268957206198472 deaths
# 21 Days of Quarantine Tested, 1.5007396487526443 deaths
# 22 Days of Quarantine Tested, 1.4834012411828652 deaths
# 23 Days of Quarantine Tested, 1.4643038829837816 deaths
# 24 Days of Quarantine Tested, 1.4479599623649404 deaths
# 25 Days of Quarantine Tested, 1.434028986924074 deaths
# 26 Days of Quarantine Tested, 1.4172515990059509 deaths
# 27 Days of Quarantine Tested, 1.4073967856509226 deaths
# 28 Days of Quarantine Tested, 1.3991578442621146 deaths
# 29 Days of Quarantine Tested, 1.3922455327726815 deaths
# 30 Days of Quarantine Tested, 1.386320363108087 deaths
# 31 Days of Quarantine Tested, 1.380954931378358 deaths
# 32 Days of Quarantine Tested, 1.3808644944135364 deaths
# 33 Days of Quarantine Tested, 1.3808644944135364 deaths
# 34 Days of Quarantine Tested, 1.3808644944135364 deaths
# 35 Days of Quarantine Tested, 1.3808644944135364 deaths
# 36 Days of Quarantine Tested, 1.3808644944135364 deaths
# 37 Days of Quarantine Tested, 1.3808644944135364 deaths
# 38 Days of Quarantine Tested, 1.3808644944135364 deaths
# 39 Days of Quarantine Tested, 1.3808644944135364 deaths
# 40 Days of Quarantine Tested, 1.3808644944135364 deaths
# 41 Days of Quarantine Tested, 1.3808644944135364 deaths
# 42 Days of Quarantine Tested, 1.3808644944135364 deaths
# 43 Days of Quarantine Tested, 1.3808644944135364 deaths
# 44 Days of Quarantine Tested, 1.3808644944135364 deaths
# 45 Days of Quarantine Tested, 1.3808644944135364 deaths
# 46 Days of Quarantine Tested, 1.3808644944135364 deaths
# 47 Days of Quarantine Tested, 1.3808644944135364 deaths
# 48 Days of Quarantine Tested, 1.3808644944135364 deaths
# 49 Days of Quarantine Tested, 1.3808644944135364 deaths
# 50 Days of Quarantine Tested, 1.3808644944135364 deaths
